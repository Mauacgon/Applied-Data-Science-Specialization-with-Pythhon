# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec

fig = plt.figure()
gspec = gridspec.GridSpec(6,6)
top_left = plt.subplot(gspec[0:2,0:3])
top_right = plt.subplot(gspec[0:2,3:], sharey = top_left)
bottom_left = plt.subplot(gspec[3:5,0:3], sharey = top_left)
bottom_right = plt.subplot(gspec[3:5,3:], sharey = top_left)

x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

top_left.hist(x1, bins = 100, density = True)
top_right.hist(x2, bins = 100, density = True)
bottom_left.hist(x3, bins = 100, density = True)
bottom_right.hist(x4, bins = 100, density = True)

top_left.set_title('Normal')
top_right.set_title('Gamma')
bottom_left.set_title('Exponential')
bottom_right.set_title('Uniform')

top_right.tick_params(axis = 'y', labelleft = 'off')
bottom_right.tick_params(axis = 'y', labelleft = 'off')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Create the figure and set the grid:

fig = plt.figure()
gspec = gridspec.GridSpec(6,6)
top_left = plt.subplot(gspec[0:2,0:3])
top_right = plt.subplot(gspec[0:2,3:], sharey = top_left)
bottom_left = plt.subplot(gspec[3:5,0:3], sharey = top_left)
bottom_right = plt.subplot(gspec[3:5,3:], sharey = top_left)

top_right.tick_params(axis = 'y', labelleft = 'off')
bottom_right.tick_params(axis = 'y', labelleft = 'off')

#Create the random variables:

x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

#Create the function:

n = 1000-100

def anim(curr):    
        if curr >= 100:
            if curr == n+100:
                a.event_source.stop()   
            for i in range(4):    
                subplots[i].cla()
                subplots[i].hist(dists[i][:curr], bins = bins[i], density = True)
                subplots[i].set_ylabel('Frequency')
                subplots[i].set_xlabel('Value')
                subplots[i].set_title('n={}'.format(curr))
            plt.tight_layout()

#Create the necessary lists for looping:
    
subplots = [top_left, top_right, bottom_left, bottom_right]
bins = [np.arange(-6,2,0.5),np.arange(-1,15,0.5), np.arange(5,20,0.5), np.arange(13.5,20.5,0.5)]
dists = [x1,x2,x3,x4]


a = animation.FuncAnimation(fig, anim, interval = 1)
# Out:
# <img src="data:image/png;base64,..." width="640">
